# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/"
# Out:
# Colab  datasets

# %%
# !pip install -q keras

# %%
# !python3 "/content/drive/My Drive/datasets/mnist_cnn1.py"
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 2018-11-06 04:44:42.404239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-11-06 04:44:42.404742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-11-06 04:44:42.404785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-11-06 04:44:43.390205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-11-06 04:44:43.390267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-11-06 04:44:43.390296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# 2018-11-06 04:44:43.390588: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2018-11-06 04:44:43.390731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10758 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# 60000/60000 [==============================] - 12s 200us/step - loss: 0.2752 - acc: 0.9198 - val_loss: 0.0630 - val_acc: 0.9798
# Epoch 2/12
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.1088 - acc: 0.9681 - val_loss: 0.0484 - val_acc: 0.9842
# Epoch 3/12
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.0871 - acc: 0.9743 - val_loss: 0.0417 - val_acc: 0.9859
# Epoch 4/12
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.0725 - acc: 0.9788 - val_loss: 0.0381 - val_acc: 0.9871
# Epoch 5/12
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.0639 - acc: 0.9806 - val_loss: 0.0355 - val_acc: 0.9880
# Epoch 6/12
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.0593 - acc: 0.9827 - val_loss: 0.0348 - val_acc: 0.9884
# Epoch 7/12
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.0547 - acc: 0.9837 - val_loss: 0.0321 - val_acc: 0.9889
# Epoch 8/12
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.0512 - acc: 0.9848 - val_loss: 0.0318 - val_acc: 0.9888
# Epoch 9/12
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.0476 - acc: 0.9856 - val_loss: 0.0301 - val_acc: 0.9893
# Epoch 10/12
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.0443 - acc: 0.9865 - val_loss: 0.0315 - val_acc: 0.9888
# Epoch 11/12
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.0423 - acc: 0.9869 - val_loss: 0.0302 - val_acc: 0.9897
# Epoch 12/12
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.0407 - acc: 0.9872 - val_loss: 0.0293 - val_acc: 0.9905
# Test loss: 0.029343118044129368
# Test accuracy: 0.9905

# %%
mnist_classifier.predict(input_fn=tf.estimator.inputs.numpy_input_fn(
      x={"x": np.array([train_data[0])]},
      shuffle=False))
